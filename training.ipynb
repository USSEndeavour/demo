# %%
M = [[1,2,4],[8,5,6],[7,8,9]]

# %%
col2=[row[1] for row in M]
col2
# Out:
# [2, 5, 8]

# %%
G = (sum(row) for row in M)
next(G)
# Out:
# 6

# %%
next(G)
# Out:
# 15

# %%
next(G)
# Out:
# 24

# %%
list(map(sum, M))
# Out:
# [6, 15, 24]

# %%
# Out:
# 54
